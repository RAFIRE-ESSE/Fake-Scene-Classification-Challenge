# %%
import argparse
import os,cv2
import random,numpy,pandas
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
import argparse
import os
import random,numpy
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
import torchvision.utils as vutils
from torchvision.models.feature_extraction import create_feature_extractor
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
seed = 999
print("Random Seed: ", seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)
# Out:
# Random Seed:  999

# %%
ngpu=1
ngf,nc = 3,3
ndf = 64

fsc_test={}

transform = transforms.Compose([
    transforms.Resize((450,450)),
    transforms.RandomRotation(15),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


#image="/kaggle/input/fake-car/WhatsApp Image 2024-11-16 at 6.36.05 PM.jpeg"
#image=cv2.cvtColor(cv2.resize(cv2.imread(image),(400,400)), cv2.COLOR_BGR2HSV)
#cv2.imwrite(f"/kaggle/working/image.jpg", image)

#image=transform(Image.open(f"/kaggle/working/image.jpg"))

for i in os.listdir('/kaggle/input/fake-scene-dataset/test'):
    fsc_test[i]=transform(Image.open(f'/kaggle/input/fake-scene-dataset/test/{i}'))

print(fsc_test["21.jpg"].shape)
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
# Out:
# torch.Size([3, 450, 450])

# %%
class EffnetModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        effnet = torchvision.models.efficientnet_v2_m(weights=torchvision.models.efficientnet.EfficientNet_V2_M_Weights.DEFAULT)
        self.model = create_feature_extractor(effnet, ['flatten'])
        self.nn_fracture = torch.nn.Sequential(
            torch.nn.Linear(1280, 1),
        )
    def forward(self, x):
        x = self.model(x)['flatten']
        x = self.nn_fracture(x)
        return x

# %%
EFF_NET = EffnetModel().float()
EFF_NET= nn.DataParallel(EFF_NET).to(device)
#EFF_NET
#EFF_NET.load_state_dict(torch.load("/kaggle/input/d/mafiosoquasar/fake-scene-classification-model-2/0.00015554654237348586 87.0.pth",weights_only=False,map_location=torch.device('cpu')))
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_m-dc08266a.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_m-dc08266a.pth
# 100%|██████████| 208M/208M [00:01<00:00, 217MB/s]

# %%
#EFF_NET(image.reshape((1, 3, 400, 400)).float().to(device)).cpu().detach().numpy()

# %%
fsc_submission=pandas.read_csv("/kaggle/input/cidaut-ai-fake-scene-classification-2024/sample_submission.csv", index_col ="image")#.to_dict('list')
sub={}

for j in ['0.00013126086560077965 30.pth']:
    print(j)
    z_add,z_total=0,0
    EFF_NET.load_state_dict(torch.load(f"/kaggle/input/d/mafiosoquasar/fake-scene-classification-model-2/{j}", 
                                       weights_only=False, map_location=torch.device('cpu')))
    for i in fsc_submission.index:
        img=fsc_test[i].reshape((1, 3, 450, 450)).float().to(device)
        fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]

pandas.DataFrame(fsc_submission)
# Out:
# 0.00013126086560077965 30.pth
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.7324129]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.442856]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.1196814]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-4.221174]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.4765505]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.90221596]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.6831553]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-5.7121205]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.8749437]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.7961602]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.3178458]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-5.082974]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.055718]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.1364465]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.3752267]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-5.5421805]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.4631336]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.2327727]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.0557414]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.3420143]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.6707605]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.187375]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.05678565]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.9918334]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.4815903]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.6110973]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.3712955]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.0096624]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.43079]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.2942667]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.387925]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.9776196]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.046308]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.4639482]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.943418]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.1642427]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.5136206]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.05780029]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.428858]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.6578054]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.0755863]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.4047356]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.3828012]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.5305834]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.2231379]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.2205467]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.2729924]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.4484859]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.36635]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.6393757]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.467845]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.1271796]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-5.175416]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.32629684]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.2090571]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.6137156]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.6668615]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.2319021]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.1302514]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.6294289]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.0150234]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.9110613]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.6028175]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.807867]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.159942]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.6278908]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.97819674]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.937458]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.905269]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-4.826001]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.1915429]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.290961]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.13696542]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.2734485]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.3139257]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.9941983]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.389636]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.942456]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.28138384]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.7155852]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.9002174]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.8921204]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-4.556572]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.143611]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-7.010463]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.4866295]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.7360548]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.2055151]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.8428125]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.31088623]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.4638834]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.3154807]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.8121706]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.35763645]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.6635804]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.75890684]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.7989006]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.3793153]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.859682]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.5667796]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.47555596]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.3456764]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.9998425]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.7099476]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.7247677]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.4289101]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-5.8344336]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.9407201]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.0836296]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.8117185]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.9475887]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-5.118001]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.2293389]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.119341]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.3704195]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.5889306]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.5648813]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-5.446511]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.384628]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.196701]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.641015]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.81784046]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.5448117]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.146253]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.0874826]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.144487]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.1840596]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.081991]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.8409514]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.0800815]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.2030276]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.020952]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.3374367]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.18007024]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.7096016]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.0821075]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.7444766]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.0131183]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.8858554]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.2942078]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.6051087]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.6504369]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.738433]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.9753189]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.6033615]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.6326227]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.0475535]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-4.970366]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.3054293]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.6923213]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.1577228]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.1805245]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.0850077]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.6502196]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.6431128]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.569295]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.789454]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.934903]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.220828]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.81908]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-2.6002164]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.165329]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.14629504]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.6067185]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.31595]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.3078144]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.0545433]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.3116367]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.1639338]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-4.6777177]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.006551]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.153316]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-1.4695472]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-3.9943466]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.3794067]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.0713663]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.7255254]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[6.701602]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7.1245937]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
# /tmp/ipykernel_23/1879662682.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-6.09251]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   fsc_submission.loc[i]['label'] = EFF_NET(img).cpu().detach().numpy()[0]
#          label
# image
# 102.jpg      1
# 108.jpg      0
# 109.jpg      0
# 111.jpg      0
# 121.jpg      1
# ...        ...
# 899.jpg      0
# 91.jpg       0
# 94.jpg       0
# 95.jpg       1
# 98.jpg       1
#
# [180 rows x 1 columns]

# %%
fsc_submission['image']=fsc_submission.index
pandas.DataFrame(fsc_submission).to_csv(f"submission.csv", index=False)
